# %%
from seirsplus.models import *
import networkx as nx

import matplotlib.pyplot as plt

# %%
numNodes = 1000
baseGraph    = nx.barabasi_albert_graph(n=numNodes, m=9)
# nx.draw(baseGraph)

# %%
options = {
    'node_color': 'black',
    'node_size': 50,
    'line_color': 'grey',
    'linewidths': 0,
    'width': 0.1,
}
nx.draw(baseGraph, **options)

# %%
baseGraph.nodes[0][]
# Out:
# {}
